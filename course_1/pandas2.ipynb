# %%
import pandas as pd

df = pd.read_csv('cities.csv')
df[['LatD']]
# Out:
#      LatD
# 0      41
# 1      42
# 2      46
# 3      42
# 4      43
# ..    ...
# 123    39
# 124    50
# 125    40
# 126    40
# 127    41
#
# [128 rows x 1 columns]

# %%
df = df[0:5]
df
# Out:
#    LatD   "LatM"   "LatS"  "NS"   "LonD"   "LonM"   "LonS"  "EW"  \
# 0    41        5       59   "N"       80       39        0   "W"
# 1    42       52       48   "N"       97       23       23   "W"
# 2    46       35       59   "N"      120       30       36   "W"
# 3    42       16       12   "N"       71       48        0   "W"
# 4    43       37       48   "N"       89       46       11   "W"
#
#                "City"  "State"
# 0        "Youngstown"       OH
# 1           "Yankton"       SD
# 2            "Yakima"       WA
# 3         "Worcester"       MA
# 4   "Wisconsin Dells"       WI

# %%
thirdRow = [False, False, True, False, False]
df[thirdRow]
# Out:
#    LatD   "LatM"   "LatS"  "NS"   "LonD"   "LonM"   "LonS"  "EW"     "City"  \
# 2    46       35       59   "N"      120       30       36   "W"   "Yakima"
#
#    "State"
# 2       WA

# %%
df = pd.read_csv('cities.csv')
condition = df['LatD'] > 45
df[condition]
# Out:
#      LatD   "LatM"   "LatS"  "NS"   "LonD"   "LonM"   "LonS"  "EW"  \
# 0      41        5       59   "N"       80       39        0   "W"
# 1      42       52       48   "N"       97       23       23   "W"
# 2      46       35       59   "N"      120       30       36   "W"
# 3      42       16       12   "N"       71       48        0   "W"
# 4      43       37       48   "N"       89       46       11   "W"
# ..    ...      ...      ...   ...      ...      ...      ...   ...
# 123    39       31       12   "N"      119       48       35   "W"
# 124    50       25       11   "N"      104       39        0   "W"
# 125    40       10       48   "N"      122       14       23   "W"
# 126    40       19       48   "N"       75       55       48   "W"
# 127    41        9       35   "N"       81       14       23   "W"
#
#                  "City"  "State"
# 0          "Youngstown"       OH
# 1             "Yankton"       SD
# 2              "Yakima"       WA
# ...

# %%
df = pd.read_csv('cities.csv')
df[ (df['LatD']>45) & (df['LatD']<50) ]
# Out:
#     LatD   "LatM"   "LatS"  "NS"   "LonD"   "LonM"   "LonS"  "EW"  \
# 2     46       35       59   "N"      120       30       36   "W"
# 6     49       52       48   "N"       97        9        0   "W"
# 10    48        9        0   "N"      103       37       12   "W"
# 17    47       25       11   "N"      120       19       11   "W"
# 28    46        4       11   "N"      118       19       48   "W"
# 33    49       16       12   "N"      123        7       12   "W"
# 34    46       55       11   "N"       98        0       36   "W"
# 54    47       14       24   "N"      122       25       48   "W"
# 68    47       40       11   "N"      117       24       36   "W"
# 78    47       35       59   "N"      122       19       48   "W"
# 83    46       29       24   "N"       84       20       59   "W"
#
#                    "City"  "State"
# 2                "Yakima"       WA
# 6              "Winnipeg"       MB
# 10            "Williston"       ND
# ...
