# %%
import pandas as pd

# %%
myList = [['Apple', 'Red'], ['Mango', 'Yellow'], ['Orange', 'Orange']]

# %%
myDataFrame = pd.DataFrame(myList)
myDataFrame
# Out:
#         0       1
# 0   Apple     Red
# 1   Mango  Yellow
# 2  Orange  Orange

# %%
myDataFrame = pd.DataFrame(myList, columns=['Fruits', 'Colors'])
myDataFrame
# Out:
#    Fruits  Colors
# 0   Apple     Red
# 1   Mango  Yellow
# 2  Orange  Orange

# %%
import pandas as pd
import numpy as np

myArray = np.array([[0,1], [2,3], [4,5]])
myDataFrame = pd.DataFrame(myArray, columns=['even', 'odd'])
myDataFrame
# Out:
#    even  odd
# 0     0    1
# 1     2    3
# 2     4    5

# %%
# using dict
import pandas as pd

myDict = {'fruits':['apple', 'orange', 'mango'], 'colors':['red', 'orange', 'yellow']}
myDataFrame = pd.DataFrame(myDict)
myDataFrame
# Out:
#    fruits  colors
# 0   apple     red
# 1  orange  orange
# 2   mango  yellow

# %%
import pandas as pd

df = pd.read_csv('cities.csv')
df
# Out:
#      LatD   "LatM"   "LatS"  "NS"   "LonD"   "LonM"   "LonS"  "EW"  \
# 0      41        5       59   "N"       80       39        0   "W"
# 1      42       52       48   "N"       97       23       23   "W"
# 2      46       35       59   "N"      120       30       36   "W"
# 3      42       16       12   "N"       71       48        0   "W"
# 4      43       37       48   "N"       89       46       11   "W"
# ..    ...      ...      ...   ...      ...      ...      ...   ...
# 123    39       31       12   "N"      119       48       35   "W"
# 124    50       25       11   "N"      104       39        0   "W"
# 125    40       10       48   "N"      122       14       23   "W"
# 126    40       19       48   "N"       75       55       48   "W"
# 127    41        9       35   "N"       81       14       23   "W"
#
#                  "City"  "State"
# 0          "Youngstown"       OH
# 1             "Yankton"       SD
# 2              "Yakima"       WA
# ...

# %%
df.set_index('LatD')
# Out:
#        "LatM"   "LatS"  "NS"   "LonD"   "LonM"   "LonS"  "EW"  \
# LatD
# 41          5       59   "N"       80       39        0   "W"
# 42         52       48   "N"       97       23       23   "W"
# 46         35       59   "N"      120       30       36   "W"
# 42         16       12   "N"       71       48        0   "W"
# 43         37       48   "N"       89       46       11   "W"
# ...       ...      ...   ...      ...      ...      ...   ...
# 39         31       12   "N"      119       48       35   "W"
# 50         25       11   "N"      104       39        0   "W"
# 40         10       48   "N"      122       14       23   "W"
# 40         19       48   "N"       75       55       48   "W"
# 41          9       35   "N"       81       14       23   "W"
#
#                   "City"  "State"
# LatD
# 41          "Youngstown"       OH
# 42             "Yankton"       SD
# 46              "Yakima"       WA
# 42           "Worcester"       MA
# ...

# %%
df.set_index("LatD", inplace=True)
df
# Out:
#        "LatM"   "LatS"  "NS"   "LonD"   "LonM"   "LonS"  "EW"  \
# LatD
# 41          5       59   "N"       80       39        0   "W"
# 42         52       48   "N"       97       23       23   "W"
# 46         35       59   "N"      120       30       36   "W"
# 42         16       12   "N"       71       48        0   "W"
# 43         37       48   "N"       89       46       11   "W"
# ...       ...      ...   ...      ...      ...      ...   ...
# 39         31       12   "N"      119       48       35   "W"
# 50         25       11   "N"      104       39        0   "W"
# 40         10       48   "N"      122       14       23   "W"
# 40         19       48   "N"       75       55       48   "W"
# 41          9       35   "N"       81       14       23   "W"
#
#                   "City"  "State"
# LatD
# 41          "Youngstown"       OH
# 42             "Yankton"       SD
# 46              "Yakima"       WA
# 42           "Worcester"       MA
# ...

# %%
df.head(4)
# Out:
#        "LatM"   "LatS"  "NS"   "LonD"   "LonM"   "LonS"  "EW"         "City"  \
# LatD
# 41          5       59   "N"       80       39        0   "W"   "Youngstown"
# 42         52       48   "N"       97       23       23   "W"      "Yankton"
# 46         35       59   "N"      120       30       36   "W"       "Yakima"
# 42         16       12   "N"       71       48        0   "W"    "Worcester"
#
#       "State"
# LatD
# 41         OH
# 42         SD
# 46         WA
# 42         MA

# %%
df.head(7)
# Out:
#        "LatM"   "LatS"  "NS"   "LonD"   "LonM"   "LonS"  "EW"  \
# LatD
# 41          5       59   "N"       80       39        0   "W"
# 42         52       48   "N"       97       23       23   "W"
# 46         35       59   "N"      120       30       36   "W"
# 42         16       12   "N"       71       48        0   "W"
# 43         37       48   "N"       89       46       11   "W"
# 36          5       59   "N"       80       15        0   "W"
# 49         52       48   "N"       97        9        0   "W"
#
#                   "City"  "State"
# LatD
# 41          "Youngstown"       OH
# 42             "Yankton"       SD
# 46              "Yakima"       WA
# 42           "Worcester"       MA
# 43     "Wisconsin Dells"       WI
# 36       "Winston-Salem"       NC
# 49            "Winnipeg"       MB

# %%
df.tail(5)
# Out:
#        "LatM"   "LatS"  "NS"   "LonD"   "LonM"   "LonS"  "EW"        "City"  \
# LatD
# 39         31       12   "N"      119       48       35   "W"        "Reno"
# 50         25       11   "N"      104       39        0   "W"      "Regina"
# 40         10       48   "N"      122       14       23   "W"   "Red Bluff"
# 40         19       48   "N"       75       55       48   "W"     "Reading"
# 41          9       35   "N"       81       14       23   "W"     "Ravenna"
#
#       "State"
# LatD
# 39         NV
# 50         SA
# 40         CA
# 40         PA
# 41        OH

# %%
df[1:4]
# Out:
#        "LatM"   "LatS"  "NS"   "LonD"   "LonM"   "LonS"  "EW"        "City"  \
# LatD
# 42         52       48   "N"       97       23       23   "W"     "Yankton"
# 46         35       59   "N"      120       30       36   "W"      "Yakima"
# 42         16       12   "N"       71       48        0   "W"   "Worcester"
#
#       "State"
# LatD
# 42         SD
# 46         WA
# 42         MA
